# %%
import pandas as pd
# Baca file Excel
df = pd.read_excel('coffe.xlsx')  # Ganti 'nama_file.xlsx' dengan nama file Excel Anda

# Simpan ke file CSV
df.to_csv('coffe.csv', index=False)  # Menyimpan DataFrame ke dalam file CSV baru

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609 entries, 0 to 608
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   drink     609 non-null    object
#  1   Volume    609 non-null    float64
#  2   Calories  609 non-null    int64
#  3   Caffeine  609 non-null    int64
#  4   type      609 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 23.9+ KB

# %%
df.head()
# Out:
#                          drink        Volume  Calories  Caffeine    type
# 0                 Costa Coffee  2.569937e+16         0       277  Coffee
# 1  Coffee Friend Brewed Coffee  2.501918e+16         0       145  Coffee
# 2           Hell Energy Coffee  2.501918e+16       150       100  Coffee
# 3           Killer Coffee (AU)  2.501918e+16         0       430  Coffee
# 4                 Nescafe Gold  2.501918e+16         0        66  Coffee

# %%
df.drop('drink', axis=1, inplace=True)

# %%
df.head(11)
# Out:
#           Volume  Calories  Caffeine    type
# 0   2.569937e+16         0       277  Coffee
# 1   2.501918e+16         0       145  Coffee
# 2   2.501918e+16       150       100  Coffee
# 3   2.501918e+16         0       430  Coffee
# 4   2.501918e+16         0        66  Coffee
# 5   2.484174e+16       170       160  Coffee
# 6   2.395453e+16        80       134  Coffee
# 7   2.010998e+06        45       155  Coffee
# 8   1.922278e+07       140       120  Coffee
# 9   1.508248e+07         0        95  Coffee
# 10  7.896124e+15         0       125  Coffee

# %%
print(df['type'].unique())
# Out:
# ['Coffee' 'Energy-Drinks' 'Soft-Drinks' 'Tea' 'Water']

# %%
#memisakhan atribut dengan label dimana x itu atribut dan y itu label
X = df[['Volume','Calories','Caffeine']]
y = df['type']


#membagi dataset menjadi data latih dan data uji
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.01, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

#menentukan  model decision tree
tree_model= DecisionTreeClassifier()

#melatih model menggunakan data latih dengan fungsi fit
tree_model= tree_model.fit(X_train,y_train)

# %%
#evaluasi model untuk meguji seberapa baik model yang digunakan dan akurasi

from sklearn.metrics import accuracy_score

y_pred =  tree_model.predict(X_test)

accuracy_score =round(accuracy_score(y_pred, y_test), 3)

print('Accuracy: ',accuracy_score)
# Out:
# Accuracy:  0.857

# %%
from sklearn.tree import DecisionTreeClassifier

#menentukan  model decision tree
tree_model= DecisionTreeClassifier()

#melatih model menggunakan data latih dengan fungsi fit
tree_model= tree_model.fit(X_train,y_train)

# %%
print(tree_model.predict([[354882, 150, 38]])[0])
# Out:
# Soft-Drinks
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#melihat visulisasi datanya decision tree
from sklearn.tree import export_graphviz

export_graphviz(tree_model,
                out_file="coffe_tree.dot",
                feature_names=['Volume','Calories','Caffeine'],
                class_names=['Coffee','Energy-Drinks','Energy-Shots','Soft-Drinks','Tea','Water'],
                rounded=True,
filled=True)

# %%
#Konversi file .dot menjadi gambar
import graphviz
with open("coffe_tree.dot") as f:
  dot_graph = f.read()
graphviz.Source(dot_graph)
